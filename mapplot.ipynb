# %%
# %pip install geopandas
# Out:
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import geopandas as gpd 
import matplotlib.pyplot as plt
import pandas as pd

# %%
gdf_swe=gpd.read_file('data/gadm41_SWE_2.json')

# %%
gdf_swe.plot()
# Out:
# <Axes: >

# %%
gdf_swe.columns
# Out:
# Index(['GID_2', 'GID_0', 'COUNTRY', 'GID_1', 'NAME_1', 'NL_NAME_1', 'NAME_2',
#        'VARNAME_2', 'NL_NAME_2', 'TYPE_2', 'ENGTYPE_2', 'CC_2', 'HASC_2',
#        'geometry'],
#       dtype='object')

# %%
gdf_vasterbotten.head()
# Out:
#           GID_2 GID_0 COUNTRY     GID_1        NAME_1 NL_NAME_1    NAME_2  \
# 206  SWE.18.1_1   SWE  Sweden  SWE.18_1  Västerbotten        NA     Åsele
# 207  SWE.18.2_1   SWE  Sweden  SWE.18_1  Västerbotten        NA  Bjurholm
# 208  SWE.18.3_1   SWE  Sweden  SWE.18_1  Västerbotten        NA   Dorotea
# 209  SWE.18.4_1   SWE  Sweden  SWE.18_1  Västerbotten        NA  Lycksele
# 210  SWE.18.5_1   SWE  Sweden  SWE.18_1  Västerbotten        NA      Malå
#
#     VARNAME_2 NL_NAME_2    TYPE_2     ENGTYPE_2 CC_2    HASC_2  \
# 206        NA        NA  Kommuner  Municipality   NA  SE.VB.AS
# 207        NA        NA  Kommuner  Municipality   NA  SE.VB.BJ
# 208        NA        NA  Kommuner  Municipality   NA  SE.VB.DO
# 209        NA        NA  Kommuner  Municipality   NA  SE.VB.LY
# 210        NA        NA  Kommuner  Municipality   NA  SE.VB.MA
#
#                                               geometry
# 206  MULTIPOLYGON (((18.78930 64.05620, 18.78950 64...
# ...

# %%
gdf_vasterbotten=gdf_swe[gdf_swe['NAME_1']=='Västerbotten']

# %%
gdf_vasterbotten.plot(edgecolor='black',facecolor='g',figsize=(12,10))
for idx, row in gdf_vasterbotten.iterrows():
    plt.text(row.geometry.centroid.x, row.geometry.centroid.y, row['NAME_2'], 
             horizontalalignment='center', fontsize=8)

plt.title('Map of Västerbotten with Each Municipality')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
# Out:
# Text(161.73079637667985, 0.5, 'Latitude')

# %%
#plot the map of Västerbotten with the municipality names
